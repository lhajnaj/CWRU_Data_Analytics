# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Define the URL
temp_units = "imperial"
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units={temp_units}&q="

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------\nData Retrieval Complete\n------------------------")
# Out:
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | hastings
# Processing Record 5 of Set 1 | flin flon
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | puerto escondido
# Processing Record 8 of Set 1 | gari
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | perth
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 1 | cockburn town
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | isangel
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | port hedland
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | araouane
# Processing Record 21 of Set 1 | lagoa
# Processing Record 22 of Set 1 | lebu
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | susa
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | oktyabrskoye
# City not found. Skipping...
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | zhuhai
# Processing Record 29 of Set 1 | plettenberg bay
# City not found. Skipping...
# Processing Record 30 of Set 1 | botou
# Processing Record 31 of Set 1 | laurel
# Processing Record 32 of Set 1 | klaksvik
# City not found. Skipping...
# Processing Record 33 of Set 1 | vilhena
# Processing Record 34 of Set 1 | birjand
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | iberia
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | rafai
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | balabac
# Processing Record 42 of Set 1 | ahipara
# Processing Record 43 of Set 1 | liverpool
# Processing Record 44 of Set 1 | takoradi
# Processing Record 45 of Set 1 | hambantota
# Processing Record 46 of Set 1 | waitati
# City not found. Skipping...
# Processing Record 47 of Set 1 | hilton head island
# Processing Record 48 of Set 1 | katsuura
# Processing Record 49 of Set 1 | avarua
# City not found. Skipping...
# Processing Record 1 of Set 2 | roebourne
# Processing Record 2 of Set 2 | margate
# Processing Record 3 of Set 2 | nanortalik
# Processing Record 4 of Set 2 | christchurch
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | coihueco
# Processing Record 8 of Set 2 | okato
# Processing Record 9 of Set 2 | provideniya
# Processing Record 10 of Set 2 | kyzyl-suu
# Processing Record 11 of Set 2 | san julian
# Processing Record 12 of Set 2 | punta cardon
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | busselton
# Processing Record 15 of Set 2 | ashtian
# Processing Record 16 of Set 2 | tasiilaq
# Processing Record 17 of Set 2 | saldanha
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | blackwater
# Processing Record 20 of Set 2 | garowe
# Processing Record 21 of Set 2 | karaton
# Processing Record 22 of Set 2 | hami
# Processing Record 23 of Set 2 | moerai
# Processing Record 24 of Set 2 | atar
# Processing Record 25 of Set 2 | khandagayty
# Processing Record 26 of Set 2 | salalah
# City not found. Skipping...
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | cabo san lucas
# Processing Record 29 of Set 2 | mar del plata
# Processing Record 30 of Set 2 | codrington
# Processing Record 31 of Set 2 | terrace bay
# Processing Record 32 of Set 2 | nawabganj
# Processing Record 33 of Set 2 | tuatapere
# City not found. Skipping...
# Processing Record 34 of Set 2 | luderitz
# Processing Record 35 of Set 2 | yellowknife
# Processing Record 36 of Set 2 | vostok
# City not found. Skipping...
# Processing Record 37 of Set 2 | kapaa
# Processing Record 38 of Set 2 | grand-santi
# City not found. Skipping...
# Processing Record 39 of Set 2 | mbour
# Processing Record 40 of Set 2 | lasa
# Processing Record 41 of Set 2 | awbari
# Processing Record 42 of Set 2 | hofn
# Processing Record 43 of Set 2 | las vegas
# Processing Record 44 of Set 2 | ushuaia
# Processing Record 45 of Set 2 | port elizabeth
# Processing Record 46 of Set 2 | severo-kurilsk
# Processing Record 47 of Set 2 | hovd
# City not found. Skipping...
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | praia
# Processing Record 1 of Set 3 | matamoros
# City not found. Skipping...
# Processing Record 2 of Set 3 | san patricio
# Processing Record 3 of Set 3 | cadiz
# Processing Record 4 of Set 3 | saint-augustin
# City not found. Skipping...
# Processing Record 5 of Set 3 | atambua
# Processing Record 6 of Set 3 | chokurdakh
# Processing Record 7 of Set 3 | roma
# Processing Record 8 of Set 3 | vaini
# Processing Record 9 of Set 3 | pangai
# Processing Record 10 of Set 3 | carnarvon
# Processing Record 11 of Set 3 | saint-georges
# Processing Record 12 of Set 3 | beringovskiy
# Processing Record 13 of Set 3 | ust-maya
# Processing Record 14 of Set 3 | fort nelson
# Processing Record 15 of Set 3 | ilo
# Processing Record 16 of Set 3 | coromandel
# Processing Record 17 of Set 3 | naze
# Processing Record 18 of Set 3 | bend
# Processing Record 19 of Set 3 | boyolangu
# Processing Record 20 of Set 3 | nemuro
# Processing Record 21 of Set 3 | svetlaya
# Processing Record 22 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 3 | bredasdorp
# Processing Record 24 of Set 3 | rudnyy
# Processing Record 25 of Set 3 | anadyr
# City not found. Skipping...
# Processing Record 26 of Set 3 | saint-denis
# Processing Record 27 of Set 3 | prince rupert
# Processing Record 28 of Set 3 | talcahuano
# Processing Record 29 of Set 3 | grindavik
# Processing Record 30 of Set 3 | oranjemund
# City not found. Skipping...
# Processing Record 31 of Set 3 | nova olimpia
# Processing Record 32 of Set 3 | lae
# Processing Record 33 of Set 3 | lata
# Processing Record 34 of Set 3 | san carlos de bariloche
# Processing Record 35 of Set 3 | angoche
# Processing Record 36 of Set 3 | ribeira grande
# Processing Record 37 of Set 3 | viedma
# Processing Record 38 of Set 3 | abnub
# Processing Record 39 of Set 3 | scarborough
# Processing Record 40 of Set 3 | geraldton
# City not found. Skipping...
# Processing Record 41 of Set 3 | yumen
# Processing Record 42 of Set 3 | ambanja
# Processing Record 43 of Set 3 | macapa
# Processing Record 44 of Set 3 | nioro
# Processing Record 45 of Set 3 | flinders
# Processing Record 46 of Set 3 | lompoc
# Processing Record 47 of Set 3 | tiksi
# Processing Record 48 of Set 3 | poopo
# City not found. Skipping...
# Processing Record 49 of Set 3 | butaritari
# Processing Record 1 of Set 4 | mount isa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 2 of Set 4 | yasnogorsk
# City not found. Skipping...
# Processing Record 3 of Set 4 | norman wells
# Processing Record 4 of Set 4 | tabou
# Processing Record 5 of Set 4 | obera
# Processing Record 6 of Set 4 | yulara
# Processing Record 7 of Set 4 | iqaluit
# Processing Record 8 of Set 4 | juneau
# Processing Record 9 of Set 4 | tashtyp
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 10 of Set 4 | saint-pierre
# Processing Record 11 of Set 4 | hamilton
# Processing Record 12 of Set 4 | pevek
# Processing Record 13 of Set 4 | souillac
# Processing Record 14 of Set 4 | rio grande
# City not found. Skipping...
# Processing Record 15 of Set 4 | mount gambier
# Processing Record 16 of Set 4 | longyearbyen
# Processing Record 17 of Set 4 | narsaq
# Processing Record 18 of Set 4 | jati
# City not found. Skipping...
# Processing Record 19 of Set 4 | pochutla
# Processing Record 20 of Set 4 | tuktoyaktuk
# Processing Record 21 of Set 4 | faya
# Processing Record 22 of Set 4 | zelenoborskiy
# Processing Record 23 of Set 4 | portland
# City not found. Skipping...
# Processing Record 24 of Set 4 | ulladulla
# Processing Record 25 of Set 4 | mongoumba
# Processing Record 26 of Set 4 | tiznit
# Processing Record 27 of Set 4 | thompson
# Processing Record 28 of Set 4 | port lincoln
# Processing Record 29 of Set 4 | oussouye
# Processing Record 30 of Set 4 | nabire
# Processing Record 31 of Set 4 | gustrow
# Processing Record 32 of Set 4 | pitimbu
# Processing Record 33 of Set 4 | pundaguitan
# Processing Record 34 of Set 4 | evans
# Processing Record 35 of Set 4 | baykit
# Processing Record 36 of Set 4 | slyudyanka
# City not found. Skipping...
# Processing Record 37 of Set 4 | castro
# Processing Record 38 of Set 4 | bandarbeyla
# Processing Record 39 of Set 4 | marawi
# Processing Record 40 of Set 4 | maner
# Processing Record 41 of Set 4 | maubin
# Processing Record 42 of Set 4 | guerrero negro
# Processing Record 43 of Set 4 | gemena
# Processing Record 44 of Set 4 | chubbuck
# Processing Record 45 of Set 4 | newtonmore
# Processing Record 46 of Set 4 | san dimas
# Processing Record 47 of Set 4 | saint-paul
# City not found. Skipping...
# Processing Record 48 of Set 4 | kamiiso
# City not found. Skipping...
# Processing Record 49 of Set 4 | santa rosa
# Processing Record 1 of Set 5 | vestmannaeyjar
# Processing Record 2 of Set 5 | tshikapa
# Processing Record 3 of Set 5 | lilienthal
# Processing Record 4 of Set 5 | pishva
# Processing Record 5 of Set 5 | sitka
# City not found. Skipping...
# Processing Record 6 of Set 5 | mahebourg
# Processing Record 7 of Set 5 | tautira
# Processing Record 8 of Set 5 | saint-philippe
# Processing Record 9 of Set 5 | alofi
# Processing Record 10 of Set 5 | airai
# Processing Record 11 of Set 5 | abu dhabi
# Processing Record 12 of Set 5 | dowa
# Processing Record 13 of Set 5 | morondava
# Processing Record 14 of Set 5 | torbay
# Processing Record 15 of Set 5 | weihe
# Processing Record 16 of Set 5 | baillif
# Processing Record 17 of Set 5 | kuytun
# Processing Record 18 of Set 5 | arraial do cabo
# Processing Record 19 of Set 5 | deputatskiy
# Processing Record 20 of Set 5 | ostrovnoy
# Processing Record 21 of Set 5 | kawalu
# Processing Record 22 of Set 5 | jumla
# Processing Record 23 of Set 5 | coquimbo
# Processing Record 24 of Set 5 | sawakin
# Processing Record 25 of Set 5 | luanda
# Processing Record 26 of Set 5 | holme
# Processing Record 27 of Set 5 | virginia beach
# Processing Record 28 of Set 5 | yar-sale
# Processing Record 29 of Set 5 | ponta pora
# Processing Record 30 of Set 5 | avenal
# Processing Record 31 of Set 5 | mezen
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 5 | nelson bay
# Processing Record 33 of Set 5 | gorontalo
# Processing Record 34 of Set 5 | tevriz
# Processing Record 35 of Set 5 | san cristobal
# Processing Record 36 of Set 5 | paidha
# Processing Record 37 of Set 5 | waipawa
# City not found. Skipping...
# Processing Record 38 of Set 5 | fiumicino
# Processing Record 39 of Set 5 | mansa
# Processing Record 40 of Set 5 | balkhash
# Processing Record 41 of Set 5 | half moon bay
# Processing Record 42 of Set 5 | vicente guerrero
# Processing Record 43 of Set 5 | taungdwingyi
# Processing Record 44 of Set 5 | port macquarie
# Processing Record 45 of Set 5 | tura
# Processing Record 46 of Set 5 | clyde river
# Processing Record 47 of Set 5 | kaliua
# Processing Record 48 of Set 5 | sabla
# Processing Record 49 of Set 5 | warmbad
# Processing Record 1 of Set 6 | alekseyevsk
# Processing Record 2 of Set 6 | aykhal
# Processing Record 3 of Set 6 | tamandare
# Processing Record 4 of Set 6 | alamos
# Processing Record 5 of Set 6 | honningsvag
# Processing Record 6 of Set 6 | cidreira
# Processing Record 7 of Set 6 | nyuksenitsa
# Processing Record 8 of Set 6 | padang
# Processing Record 9 of Set 6 | las choapas
# Processing Record 10 of Set 6 | paamiut
# Processing Record 11 of Set 6 | acari
# Processing Record 12 of Set 6 | gat
# Processing Record 13 of Set 6 | nikolskoye
# Processing Record 14 of Set 6 | ferme-neuve
# Processing Record 15 of Set 6 | east london
# Processing Record 16 of Set 6 | vardo
# Processing Record 17 of Set 6 | karratha
# Processing Record 18 of Set 6 | pelym
# Processing Record 19 of Set 6 | kahului
# Processing Record 20 of Set 6 | mason city
# Processing Record 21 of Set 6 | nara
# Processing Record 22 of Set 6 | bassila
# Processing Record 23 of Set 6 | sassandra
# Processing Record 24 of Set 6 | sambava
# Processing Record 25 of Set 6 | dikson
# Processing Record 26 of Set 6 | bambanglipuro
# Processing Record 27 of Set 6 | caravelas
# Processing Record 28 of Set 6 | elmadag
# City not found. Skipping...
# Processing Record 29 of Set 6 | kudahuvadhoo
# City not found. Skipping...
# Processing Record 30 of Set 6 | richards bay
# City not found. Skipping...
# Processing Record 31 of Set 6 | parati
# City not found. Skipping...
# Processing Record 32 of Set 6 | mount pleasant
# Processing Record 33 of Set 6 | greenville
# Processing Record 34 of Set 6 | pathein
# Processing Record 35 of Set 6 | inhambane
# Processing Record 36 of Set 6 | port keats
# Processing Record 37 of Set 6 | lufilufi
# Processing Record 38 of Set 6 | lujan
# Processing Record 39 of Set 6 | labuhan
# Processing Record 40 of Set 6 | oistins
# Processing Record 41 of Set 6 | grand river south east
# Processing Record 42 of Set 6 | muroto
# Processing Record 43 of Set 6 | chicama
# Processing Record 44 of Set 6 | rimbey
# Processing Record 45 of Set 6 | bonavista
# Processing Record 46 of Set 6 | pittsfield
# City not found. Skipping...
# Processing Record 47 of Set 6 | aanekoski
# Processing Record 48 of Set 6 | adrar
# Processing Record 49 of Set 6 | dunedin
# Processing Record 1 of Set 7 | coihaique
# Processing Record 2 of Set 7 | manta
# Processing Record 3 of Set 7 | haifa
# Processing Record 4 of Set 7 | crestview
# Processing Record 5 of Set 7 | burley
# Processing Record 6 of Set 7 | bayan
# Processing Record 7 of Set 7 | egvekinot
# Processing Record 8 of Set 7 | ouango
# Processing Record 9 of Set 7 | samarai
# Processing Record 10 of Set 7 | nantucket
# Processing Record 11 of Set 7 | ambikapur
# Processing Record 12 of Set 7 | shimoda
# Processing Record 13 of Set 7 | cayenne
# Processing Record 14 of Set 7 | mys shmidta
# Processing Record 15 of Set 7 | port-cartier
# Processing Record 16 of Set 7 | xuddur
# Processing Record 17 of Set 7 | shieli
# Processing Record 18 of Set 7 | agadir
# Processing Record 19 of Set 7 | jurm
# Processing Record 20 of Set 7 | saucillo
# City not found. Skipping...
# Processing Record 21 of Set 7 | asekeyevo
# Processing Record 22 of Set 7 | poum
# Processing Record 23 of Set 7 | marataizes
# Processing Record 24 of Set 7 | biak
# Processing Record 25 of Set 7 | faanui
# Processing Record 26 of Set 7 | vao
# Processing Record 27 of Set 7 | broome
# Processing Record 28 of Set 7 | biscarrosse
# Processing Record 29 of Set 7 | husavik
# Processing Record 30 of Set 7 | lumajang
# Processing Record 31 of Set 7 | kruisfontein
# Processing Record 32 of Set 7 | grand gaube
# Processing Record 33 of Set 7 | lagos
# Processing Record 34 of Set 7 | khanpur
# City not found. Skipping...
# Processing Record 35 of Set 7 | ayagoz
# Processing Record 36 of Set 7 | aracati
# Processing Record 37 of Set 7 | hondo
# Processing Record 38 of Set 7 | aksarka
# Processing Record 39 of Set 7 | pacifica
# Processing Record 40 of Set 7 | namtsy
# Processing Record 41 of Set 7 | victoria
# Processing Record 42 of Set 7 | hurricane
# Processing Record 43 of Set 7 | numan
# Processing Record 44 of Set 7 | karachi
# Processing Record 45 of Set 7 | luan
# Processing Record 46 of Set 7 | fort morgan
# Processing Record 47 of Set 7 | courtenay
# Processing Record 48 of Set 7 | gazojak
# Processing Record 49 of Set 7 | eganville
# Processing Record 1 of Set 8 | maple creek
# City not found. Skipping...
# Processing Record 2 of Set 8 | riva
# Processing Record 3 of Set 8 | morrinhos
# Processing Record 4 of Set 8 | jericho
# Processing Record 5 of Set 8 | shisui
# Processing Record 6 of Set 8 | wajid
# Processing Record 7 of Set 8 | hualmay
# Processing Record 8 of Set 8 | yantzaza
# Processing Record 9 of Set 8 | jambi
# Processing Record 10 of Set 8 | ruteng
# Processing Record 11 of Set 8 | kaitangata
# Processing Record 12 of Set 8 | friedberg
# Processing Record 13 of Set 8 | boyuibe
# Processing Record 14 of Set 8 | jaca
# Processing Record 15 of Set 8 | tholen
# Processing Record 16 of Set 8 | tiarei
# Processing Record 17 of Set 8 | esperance
# Processing Record 18 of Set 8 | chapais
# Processing Record 19 of Set 8 | verkhnyaya inta
# Processing Record 20 of Set 8 | seoul
# Processing Record 21 of Set 8 | monteagudo
# Processing Record 22 of Set 8 | hasaki
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 23 of Set 8 | talnakh
# Processing Record 24 of Set 8 | aklavik
# City not found. Skipping...
# Processing Record 25 of Set 8 | san ignacio de sabaneta
# City not found. Skipping...
# Processing Record 26 of Set 8 | saskylakh
# Processing Record 27 of Set 8 | sukhothai
# Processing Record 28 of Set 8 | nueva loja
# Processing Record 29 of Set 8 | cherskiy
# Processing Record 30 of Set 8 | maxixe
# Processing Record 31 of Set 8 | acapulco
# City not found. Skipping...
# Processing Record 32 of Set 8 | pangobilian
# Processing Record 33 of Set 8 | kirakira
# Processing Record 34 of Set 8 | bereda
# Processing Record 35 of Set 8 | nyakabindi
# Processing Record 36 of Set 8 | santa maria
# Processing Record 37 of Set 8 | warrington
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of Set 8 | luganville
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 of Set 8 | hobyo
# Processing Record 40 of Set 8 | dergachi
# Processing Record 41 of Set 8 | komatipoort
# Processing Record 42 of Set 8 | east moline
# Processing Record 43 of Set 8 | shimanovsk
# Processing Record 44 of Set 8 | toribio
# Processing Record 45 of Set 8 | tevaitoa
# City not found. Skipping...
# Processing Record 46 of Set 8 | khandbari
# Processing Record 47 of Set 8 | ponta delgada
# Processing Record 48 of Set 8 | sidi ali
# Processing Record 49 of Set 8 | launceston
# City not found. Skipping...
# Processing Record 1 of Set 9 | yueyang
# Processing Record 2 of Set 9 | mocuba
# Processing Record 3 of Set 9 | havre-saint-pierre
# Processing Record 4 of Set 9 | naron
# Processing Record 5 of Set 9 | kidal
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 9 | maniitsoq
# Processing Record 7 of Set 9 | waingapu
# Processing Record 8 of Set 9 | skibbereen
# Processing Record 9 of Set 9 | kristiansund
# Processing Record 10 of Set 9 | whitehorse
# Processing Record 11 of Set 9 | valeggio sul mincio
# Processing Record 12 of Set 9 | maba
# Processing Record 13 of Set 9 | ancud
# Processing Record 14 of Set 9 | kushalgarh
# Processing Record 15 of Set 9 | ambalavao
# City not found. Skipping...
# Processing Record 16 of Set 9 | gloversville
# Processing Record 17 of Set 9 | srednekolymsk
# Processing Record 18 of Set 9 | concordia
# City not found. Skipping...
# Processing Record 19 of Set 9 | houma
# Processing Record 20 of Set 9 | sobolevo
# Processing Record 21 of Set 9 | muros
# Processing Record 22 of Set 9 | taksimo
# Processing Record 23 of Set 9 | praya
# City not found. Skipping...
# Processing Record 24 of Set 9 | huarmey
# Processing Record 25 of Set 9 | pisco
# Processing Record 26 of Set 9 | necochea
# City not found. Skipping...
# Processing Record 27 of Set 9 | santa rosalia
# Processing Record 28 of Set 9 | kyshtovka
# Processing Record 29 of Set 9 | bushehr
# Processing Record 30 of Set 9 | florianopolis
# Processing Record 31 of Set 9 | shingu
# Processing Record 32 of Set 9 | ziro
# Processing Record 33 of Set 9 | kushima
# City not found. Skipping...
# Processing Record 34 of Set 9 | kaniama
# Processing Record 35 of Set 9 | pskov
# Processing Record 36 of Set 9 | bubaque
# Processing Record 37 of Set 9 | bahile
# Processing Record 38 of Set 9 | joroan
# City not found. Skipping...
# Processing Record 39 of Set 9 | namibe
# City not found. Skipping...
# Processing Record 40 of Set 9 | ishigaki
# Processing Record 41 of Set 9 | yantal
# Processing Record 42 of Set 9 | yakeshi
# Processing Record 43 of Set 9 | mwinilunga
# Processing Record 44 of Set 9 | srandakan
# Processing Record 45 of Set 9 | qandala
# Processing Record 46 of Set 9 | ixtapa
# Processing Record 47 of Set 9 | nuevo imperial
# Processing Record 48 of Set 9 | barinitas
# City not found. Skipping...
# Processing Record 49 of Set 9 | strugari
# City not found. Skipping...
# Processing Record 1 of Set 10 | constantine
# Processing Record 2 of Set 10 | chimbarongo
# City not found. Skipping...
# Processing Record 3 of Set 10 | kloulklubed
# Processing Record 4 of Set 10 | merauke
# Processing Record 5 of Set 10 | mogadishu
# Processing Record 6 of Set 10 | rio gallegos
# Processing Record 7 of Set 10 | wonthaggi
# Processing Record 8 of Set 10 | sao filipe
# Processing Record 9 of Set 10 | ambilobe
# Processing Record 10 of Set 10 | cubuk
# Processing Record 11 of Set 10 | nouadhibou
# Processing Record 12 of Set 10 | cap malheureux
# Processing Record 13 of Set 10 | berezovka
# Processing Record 14 of Set 10 | schonebeck
# Processing Record 15 of Set 10 | roald
# Processing Record 16 of Set 10 | pangnirtung
# Processing Record 17 of Set 10 | marquette
# City not found. Skipping...
# Processing Record 18 of Set 10 | ouadda
# Processing Record 19 of Set 10 | batagay-alyta
# Processing Record 20 of Set 10 | edea
# Processing Record 21 of Set 10 | louth
# Processing Record 22 of Set 10 | nyagan
# Processing Record 23 of Set 10 | laguna
# Processing Record 24 of Set 10 | fort-shevchenko
# Processing Record 25 of Set 10 | recke
# Processing Record 26 of Set 10 | lianzhou
# Processing Record 27 of Set 10 | sungaipenuh
# Processing Record 28 of Set 10 | ahuimanu
# Processing Record 29 of Set 10 | marondera
# City not found. Skipping...
# Processing Record 30 of Set 10 | waharoa
# City not found. Skipping...
# Processing Record 31 of Set 10 | bilibino
# Processing Record 32 of Set 10 | khatanga
# Processing Record 33 of Set 10 | santa marinella
# Processing Record 34 of Set 10 | dhanera
# City not found. Skipping...
# Processing Record 35 of Set 10 | kangaatsiaq
# Processing Record 36 of Set 10 | ghanzi
# City not found. Skipping...
# Processing Record 37 of Set 10 | axim
# Processing Record 38 of Set 10 | tupik
# Processing Record 39 of Set 10 | sioux lookout
# Processing Record 40 of Set 10 | homer
# Processing Record 41 of Set 10 | mangrol
# City not found. Skipping...
# Processing Record 42 of Set 10 | villarrica
# Processing Record 43 of Set 10 | sisimiut
# City not found. Skipping...
# Processing Record 44 of Set 10 | tete
# City not found. Skipping...
# Processing Record 45 of Set 10 | chuy
# Processing Record 46 of Set 10 | dingle
# Processing Record 47 of Set 10 | sabha
# Processing Record 48 of Set 10 | maragogi
# Processing Record 49 of Set 10 | suzhou
# Processing Record 1 of Set 11 | overyata
# Processing Record 2 of Set 11 | wichita falls
# Processing Record 3 of Set 11 | les mureaux
# Processing Record 4 of Set 11 | lancaster
# City not found. Skipping...
# Processing Record 5 of Set 11 | matara
# Processing Record 6 of Set 11 | harper
# Processing Record 7 of Set 11 | fort william
# Processing Record 8 of Set 11 | lishui
# Processing Record 9 of Set 11 | kavieng
# Processing Record 10 of Set 11 | bucak
# City not found. Skipping...
# Processing Record 11 of Set 11 | rawson
# Processing Record 12 of Set 11 | ruiz
# Processing Record 13 of Set 11 | casper
# Processing Record 14 of Set 11 | san jeronimo
# Processing Record 15 of Set 11 | itarema
# Processing Record 16 of Set 11 | eseka
# Processing Record 17 of Set 11 | sao felix do xingu
# Processing Record 18 of Set 11 | kieta
# Processing Record 19 of Set 11 | haines junction
# Processing Record 20 of Set 11 | imeni poliny osipenko
# Processing Record 21 of Set 11 | chunskiy
# Processing Record 22 of Set 11 | sinnamary
# Processing Record 23 of Set 11 | sistranda
# Processing Record 24 of Set 11 | neka
# Processing Record 25 of Set 11 | boli
# Processing Record 26 of Set 11 | lavrentiya
# Processing Record 27 of Set 11 | sartell
# Processing Record 28 of Set 11 | coueron
# Processing Record 29 of Set 11 | sao luiz gonzaga
# City not found. Skipping...
# Processing Record 30 of Set 11 | jalu
# Processing Record 31 of Set 11 | carbonia
# Processing Record 32 of Set 11 | mayna
# Processing Record 33 of Set 11 | tual
# Processing Record 34 of Set 11 | opuwo
# Processing Record 35 of Set 11 | never
# Processing Record 36 of Set 11 | springdale
# Processing Record 37 of Set 11 | mbalmayo
# Processing Record 38 of Set 11 | spasskoye
# Processing Record 39 of Set 11 | nayudupeta
# Processing Record 40 of Set 11 | tinogboc
# Processing Record 41 of Set 11 | uige
# Processing Record 42 of Set 11 | pangody
# Processing Record 43 of Set 11 | killybegs
# Processing Record 44 of Set 11 | xai-xai
# Processing Record 45 of Set 11 | gayny
# Processing Record 46 of Set 11 | san miguel de cauri
# Processing Record 47 of Set 11 | ola
# Processing Record 48 of Set 11 | meulaboh
# Processing Record 49 of Set 11 | omboue
# Processing Record 1 of Set 12 | bayburt
# Processing Record 2 of Set 12 | lafiagi
# Processing Record 3 of Set 12 | bagdarin
# Processing Record 4 of Set 12 | fortuna
# Processing Record 5 of Set 12 | aleksandro-nevskiy
# City not found. Skipping...
# Processing Record 6 of Set 12 | shyryayeve
# Processing Record 7 of Set 12 | khani
# Processing Record 8 of Set 12 | leningradskiy
# Processing Record 9 of Set 12 | passos
# Processing Record 10 of Set 12 | xiaoweizhai
# ------------------------
# Data Retrieval Complete
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictionary for establishing dataframe
weather_dict = {
    "City":city_two,
    "Cloudiness":cloudinesses,
    "Country":countries,
    "Date":dates,
    "Humidity":humidities,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds
}

# Establish dataframe
weather_dataframe = pd.DataFrame(weather_dict)

weather_dataframe.count()
# Out:
# City          549
# Cloudiness    549
# Country       549
# Date          549
# Humidity      549
# Lat           549
# Lng           549
# Max Temp      549
# Wind Speed    549
# dtype: int64

# %%
# output data to csv
weather_dataframe.to_csv(output_data_file)

# %%
# show the top of the dataframe
weather_dataframe.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  new norfolk          75      LR  1568048725        94   6.65  -10.59
# 1      rikitea          85      PF  1568048761        61 -23.12 -134.97
# 2     hermanus           0      ZA  1568048761        87 -34.42   19.24
# 3     hastings         100      NZ  1568048761        92 -39.64  176.84
# 4    flin flon           0      FR  1568048761        45  48.50    6.66
#
#    Max Temp  Wind Speed
# 0     78.80        6.93
# 1     69.17        9.04
# 2     63.00        6.89
# 3     35.69        0.18
# 4     64.40        4.70

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Max Temp"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature (09/09/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures/fig1.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Humidity"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Humidity (09/09/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures/fig2.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness (09/09/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures/fig3.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed (09/09/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures/fig4.png")
plt.show()

# %% [markdown]
# # ANALYSIS
# ----
#
# Observable Trend on "City Latitude vs. Max Temperature": The data goes to prove that the weather gets hotter as we get closer to the equator (0*).
#
# Observable Trend on "City Latitude vs. Humidity": Most of the data points seem to be above the 50% "Humidity" mark. Thurmore, many of the data points show a clear favoritism towards there being more humidity as we go futher up in latitude.
#
# Observable Trend on "City Latitude vs. Cloudiness": I see no strong correlation between a city's latitude and how cloudy it is. The data seems very balanced. We should take note however, of the three rows of possible trends represented at the 0%, 75% and 100% "Cloudiness."
#
# Observable Trend on "City Latitude vs. Wind Speed": The data shows that most of the Wind Speeds are between 0 and 15 "mph" regardless of the latitdude of a city. Thus, I am unable to see a correlation between the latitude of a city and how windy it is.
