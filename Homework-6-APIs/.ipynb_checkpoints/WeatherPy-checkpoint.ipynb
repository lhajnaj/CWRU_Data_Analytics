# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Define the URL
temp_units = "imperial"
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units={temp_units}&q="

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 588

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------\nData Retrieval Complete\n------------------------")
# Out:
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | andilamena
# Processing Record 4 of Set 1 | tlacotepec
# Processing Record 5 of Set 1 | mys shmidta
# Processing Record 6 of Set 1 | mega
# Processing Record 7 of Set 1 | hamilton
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | russell
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | morlaix
# Processing Record 15 of Set 1 | panacan
# Processing Record 16 of Set 1 | cuamba
# City not found. Skipping...
# Processing Record 17 of Set 1 | guerrero negro
# Processing Record 18 of Set 1 | ardakan
# Processing Record 19 of Set 1 | hithadhoo
# City not found. Skipping...
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | cuiaba
# Processing Record 22 of Set 1 | torbay
# Processing Record 23 of Set 1 | calvinia
# Processing Record 24 of Set 1 | geraldton
# Processing Record 25 of Set 1 | beloha
# Processing Record 26 of Set 1 | clyde river
# City not found. Skipping...
# Processing Record 27 of Set 1 | fare
# Processing Record 28 of Set 1 | pevek
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 1 | soria
# Processing Record 30 of Set 1 | sambava
# Processing Record 31 of Set 1 | yeppoon
# Processing Record 32 of Set 1 | goderich
# Processing Record 33 of Set 1 | arraial do cabo
# Processing Record 34 of Set 1 | san patricio
# Processing Record 35 of Set 1 | airai
# City not found. Skipping...
# Processing Record 36 of Set 1 | gacko
# Processing Record 37 of Set 1 | bridlington
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | brownwood
# Processing Record 40 of Set 1 | pereslavl-zalesskiy
# City not found. Skipping...
# Processing Record 41 of Set 1 | kudahuvadhoo
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | hermanus
# City not found. Skipping...
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | bethel
# Processing Record 46 of Set 1 | longyearbyen
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | kargasok
# Processing Record 49 of Set 1 | yerbogachen
# Processing Record 1 of Set 2 | asyut
# Processing Record 2 of Set 2 | jamestown
# City not found. Skipping...
# Processing Record 3 of Set 2 | cidreira
# Processing Record 4 of Set 2 | srednekolymsk
# Processing Record 5 of Set 2 | esperance
# Processing Record 6 of Set 2 | letlhakane
# Processing Record 7 of Set 2 | titay
# Processing Record 8 of Set 2 | moose factory
# Processing Record 9 of Set 2 | kodiak
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 10 of Set 2 | garowe
# Processing Record 11 of Set 2 | paamiut
# Processing Record 12 of Set 2 | tilichiki
# Processing Record 13 of Set 2 | tomatlan
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | solnechnyy
# Processing Record 16 of Set 2 | khatanga
# Processing Record 17 of Set 2 | hilo
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | hailey
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | kapaa
# Processing Record 23 of Set 2 | vao
# Processing Record 24 of Set 2 | maragogi
# Processing Record 25 of Set 2 | hobart
# City not found. Skipping...
# Processing Record 26 of Set 2 | cape coast
# Processing Record 27 of Set 2 | languyan
# Processing Record 28 of Set 2 | upernavik
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | katav-ivanovsk
# Processing Record 31 of Set 2 | douglas
# Processing Record 32 of Set 2 | ahipara
# Processing Record 33 of Set 2 | takoradi
# Processing Record 34 of Set 2 | half moon bay
# Processing Record 35 of Set 2 | port hardy
# Processing Record 36 of Set 2 | shimoda
# City not found. Skipping...
# Processing Record 37 of Set 2 | chuy
# City not found. Skipping...
# Processing Record 38 of Set 2 | badajoz
# Processing Record 39 of Set 2 | haines junction
# Processing Record 40 of Set 2 | saldanha
# City not found. Skipping...
# Processing Record 41 of Set 2 | las vegas
# Processing Record 42 of Set 2 | hobyo
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | albany
# Processing Record 45 of Set 2 | ostrovnoy
# Processing Record 46 of Set 2 | sassuolo
# Processing Record 47 of Set 2 | tanabe
# Processing Record 48 of Set 2 | kuminskiy
# Processing Record 49 of Set 2 | castro
# Processing Record 1 of Set 3 | narsaq
# Processing Record 2 of Set 3 | fortuna
# City not found. Skipping...
# Processing Record 3 of Set 3 | mataura
# Processing Record 4 of Set 3 | bulawayo
# Processing Record 5 of Set 3 | pravokumskoye
# Processing Record 6 of Set 3 | celestun
# Processing Record 7 of Set 3 | norman wells
# Processing Record 8 of Set 3 | nouadhibou
# Processing Record 9 of Set 3 | champerico
# City not found. Skipping...
# Processing Record 10 of Set 3 | labytnangi
# Processing Record 11 of Set 3 | yumen
# Processing Record 12 of Set 3 | mehamn
# Processing Record 13 of Set 3 | washougal
# Processing Record 14 of Set 3 | kavieng
# Processing Record 15 of Set 3 | ankang
# Processing Record 16 of Set 3 | rio cuarto
# Processing Record 17 of Set 3 | flinders
# Processing Record 18 of Set 3 | teluk nibung
# Processing Record 19 of Set 3 | namibe
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 20 of Set 3 | naze
# Processing Record 21 of Set 3 | san cristobal
# Processing Record 22 of Set 3 | bandarbeyla
# Processing Record 23 of Set 3 | port elizabeth
# Processing Record 24 of Set 3 | faanui
# Processing Record 25 of Set 3 | shirokiy
# Processing Record 26 of Set 3 | dengzhou
# Processing Record 27 of Set 3 | san pedro
# Processing Record 28 of Set 3 | alyangula
# Processing Record 29 of Set 3 | sao filipe
# Processing Record 30 of Set 3 | bredasdorp
# City not found. Skipping...
# Processing Record 31 of Set 3 | kavaratti
# City not found. Skipping...
# Processing Record 32 of Set 3 | havelock
# City not found. Skipping...
# Processing Record 33 of Set 3 | avarua
# Processing Record 34 of Set 3 | dikson
# Processing Record 35 of Set 3 | casablanca
# Processing Record 36 of Set 3 | shalinskoye
# Processing Record 37 of Set 3 | mezapa
# Processing Record 38 of Set 3 | zhigansk
# Processing Record 39 of Set 3 | puerto colombia
# City not found. Skipping...
# Processing Record 40 of Set 3 | kloulklubed
# Processing Record 41 of Set 3 | mbalmayo
# Processing Record 42 of Set 3 | lasa
# Processing Record 43 of Set 3 | saskylakh
# Processing Record 44 of Set 3 | haapiti
# Processing Record 45 of Set 3 | nikolskoye
# Processing Record 46 of Set 3 | sawakin
# Processing Record 47 of Set 3 | tiksi
# Processing Record 48 of Set 3 | alibag
# Processing Record 49 of Set 3 | pangnirtung
# Processing Record 1 of Set 4 | monteiro
# Processing Record 2 of Set 4 | anito
# Processing Record 3 of Set 4 | verkhnyaya inta
# Processing Record 4 of Set 4 | coihaique
# Processing Record 5 of Set 4 | stepnyak
# Processing Record 6 of Set 4 | koslan
# City not found. Skipping...
# Processing Record 7 of Set 4 | portland
# Processing Record 8 of Set 4 | yatou
# Processing Record 9 of Set 4 | constitucion
# Processing Record 10 of Set 4 | mahebourg
# City not found. Skipping...
# Processing Record 11 of Set 4 | lata
# Processing Record 12 of Set 4 | semirom
# Processing Record 13 of Set 4 | talnakh
# City not found. Skipping...
# Processing Record 14 of Set 4 | homer
# Processing Record 15 of Set 4 | williamsport
# Processing Record 16 of Set 4 | puerto escondido
# Processing Record 17 of Set 4 | erenhot
# Processing Record 18 of Set 4 | quelimane
# Processing Record 19 of Set 4 | lebu
# Processing Record 20 of Set 4 | mount gambier
# City not found. Skipping...
# Processing Record 21 of Set 4 | thompson
# Processing Record 22 of Set 4 | ouadda
# City not found. Skipping...
# Processing Record 23 of Set 4 | yar-sale
# Processing Record 24 of Set 4 | iquique
# Processing Record 25 of Set 4 | cherskiy
# Processing Record 26 of Set 4 | ambilobe
# Processing Record 27 of Set 4 | kawalu
# City not found. Skipping...
# Processing Record 28 of Set 4 | ribeira grande
# Processing Record 29 of Set 4 | aksu
# Processing Record 30 of Set 4 | sinjar
# City not found. Skipping...
# Processing Record 31 of Set 4 | rantepao
# Processing Record 32 of Set 4 | baoma
# Processing Record 33 of Set 4 | shingu
# City not found. Skipping...
# Processing Record 34 of Set 4 | mizur
# Processing Record 35 of Set 4 | ponta do sol
# Processing Record 36 of Set 4 | katsuura
# Processing Record 37 of Set 4 | karwar
# Processing Record 38 of Set 4 | lavrentiya
# Processing Record 39 of Set 4 | plettenberg bay
# City not found. Skipping...
# Processing Record 40 of Set 4 | qaanaaq
# Processing Record 41 of Set 4 | saint-philippe
# Processing Record 42 of Set 4 | rio gallegos
# Processing Record 43 of Set 4 | scarborough
# Processing Record 44 of Set 4 | cayenne
# Processing Record 45 of Set 4 | poum
# Processing Record 46 of Set 4 | mount pleasant
# Processing Record 47 of Set 4 | izumo
# Processing Record 48 of Set 4 | tessalit
# Processing Record 49 of Set 4 | muravlenko
# Processing Record 1 of Set 5 | severo-kurilsk
# Processing Record 2 of Set 5 | luderitz
# City not found. Skipping...
# Processing Record 3 of Set 5 | east london
# Processing Record 4 of Set 5 | bambous virieux
# Processing Record 5 of Set 5 | noumea
# Processing Record 6 of Set 5 | santa clara
# City not found. Skipping...
# Processing Record 7 of Set 5 | north platte
# City not found. Skipping...
# Processing Record 8 of Set 5 | waipawa
# Processing Record 9 of Set 5 | santa cruz
# Processing Record 10 of Set 5 | limbang
# Processing Record 11 of Set 5 | nome
# Processing Record 12 of Set 5 | sitka
# Processing Record 13 of Set 5 | bilibino
# Processing Record 14 of Set 5 | havre-saint-pierre
# Processing Record 15 of Set 5 | sola
# Processing Record 16 of Set 5 | oktyabrskoye
# City not found. Skipping...
# Processing Record 17 of Set 5 | puerto cabezas
# Processing Record 18 of Set 5 | huron
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 5 | port blair
# Processing Record 20 of Set 5 | tazovskiy
# City not found. Skipping...
# Processing Record 21 of Set 5 | jiwani
# Processing Record 22 of Set 5 | arlit
# Processing Record 23 of Set 5 | thessalon
# Processing Record 24 of Set 5 | fukue
# Processing Record 25 of Set 5 | dunedin
# City not found. Skipping...
# Processing Record 26 of Set 5 | kitimat
# Processing Record 27 of Set 5 | zhanaozen
# Processing Record 28 of Set 5 | vardo
# City not found. Skipping...
# Processing Record 29 of Set 5 | provideniya
# Processing Record 30 of Set 5 | vostok
# Processing Record 31 of Set 5 | ilmatsalu
# Processing Record 32 of Set 5 | coari
# City not found. Skipping...
# Processing Record 33 of Set 5 | ilulissat
# Processing Record 34 of Set 5 | okha
# City not found. Skipping...
# Processing Record 35 of Set 5 | kruisfontein
# Processing Record 36 of Set 5 | dongying
# Processing Record 37 of Set 5 | chai nat
# Processing Record 38 of Set 5 | klaksvik
# Processing Record 39 of Set 5 | iralaya
# City not found. Skipping...
# Processing Record 40 of Set 5 | aitape
# Processing Record 41 of Set 5 | port-de-bouc
# Processing Record 42 of Set 5 | hasaki
# Processing Record 43 of Set 5 | phonhong
# Processing Record 44 of Set 5 | sao desiderio
# Processing Record 45 of Set 5 | margate
# Processing Record 46 of Set 5 | east wenatchee bench
# Processing Record 47 of Set 5 | wanaka
# Processing Record 48 of Set 5 | dawson creek
# Processing Record 49 of Set 5 | apatou
# Processing Record 1 of Set 6 | soe
# Processing Record 2 of Set 6 | kimberley
# Processing Record 3 of Set 6 | udimskiy
# Processing Record 4 of Set 6 | novovasylivka
# Processing Record 5 of Set 6 | ossora
# Processing Record 6 of Set 6 | port augusta
# Processing Record 7 of Set 6 | san ramon de la nueva oran
# Processing Record 8 of Set 6 | cyangugu
# Processing Record 9 of Set 6 | victoria
# Processing Record 10 of Set 6 | samarai
# Processing Record 11 of Set 6 | yinchuan
# Processing Record 12 of Set 6 | ayr
# Processing Record 13 of Set 6 | turbat
# Processing Record 14 of Set 6 | amga
# City not found. Skipping...
# Processing Record 15 of Set 6 | saint-augustin
# Processing Record 16 of Set 6 | sagaing
# Processing Record 17 of Set 6 | ulaangom
# Processing Record 18 of Set 6 | uvat
# Processing Record 19 of Set 6 | tual
# Processing Record 20 of Set 6 | skibbereen
# Processing Record 21 of Set 6 | ullapool
# City not found. Skipping...
# Processing Record 22 of Set 6 | kota bahru
# Processing Record 23 of Set 6 | lac-megantic
# Processing Record 24 of Set 6 | lyubech
# City not found. Skipping...
# Processing Record 25 of Set 6 | salvador
# Processing Record 26 of Set 6 | hualmay
# Processing Record 27 of Set 6 | carbonia
# Processing Record 28 of Set 6 | waingapu
# Processing Record 29 of Set 6 | lauterbach
# Processing Record 30 of Set 6 | chancay
# Processing Record 31 of Set 6 | grand gaube
# City not found. Skipping...
# Processing Record 32 of Set 6 | bocaiuva
# Processing Record 33 of Set 6 | codrington
# Processing Record 34 of Set 6 | komsomolskiy
# Processing Record 35 of Set 6 | ancud
# Processing Record 36 of Set 6 | taksimo
# Processing Record 37 of Set 6 | leningradskiy
# Processing Record 38 of Set 6 | lompoc
# Processing Record 39 of Set 6 | vanavara
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 40 of Set 6 | valparaiso
# Processing Record 41 of Set 6 | baicheng
# Processing Record 42 of Set 6 | husavik
# Processing Record 43 of Set 6 | jogindarnagar
# Processing Record 44 of Set 6 | jalu
# Processing Record 45 of Set 6 | port-gentil
# City not found. Skipping...
# Processing Record 46 of Set 6 | suzaka
# Processing Record 47 of Set 6 | antalaha
# City not found. Skipping...
# Processing Record 48 of Set 6 | fredericton
# Processing Record 49 of Set 6 | bubaque
# Processing Record 1 of Set 7 | carballo
# Processing Record 2 of Set 7 | kokopo
# Processing Record 3 of Set 7 | carnarvon
# Processing Record 4 of Set 7 | buala
# City not found. Skipping...
# Processing Record 5 of Set 7 | mchinji
# City not found. Skipping...
# Processing Record 6 of Set 7 | yacuiba
# Processing Record 7 of Set 7 | souillac
# Processing Record 8 of Set 7 | egvekinot
# Processing Record 9 of Set 7 | kupang
# Processing Record 10 of Set 7 | monrovia
# Processing Record 11 of Set 7 | aklavik
# Processing Record 12 of Set 7 | mwingi
# Processing Record 13 of Set 7 | kulhudhuffushi
# Processing Record 14 of Set 7 | karpogory
# Processing Record 15 of Set 7 | drumheller
# Processing Record 16 of Set 7 | sompeta
# Processing Record 17 of Set 7 | kaitangata
# Processing Record 18 of Set 7 | tekkali
# Processing Record 19 of Set 7 | kutoarjo
# Processing Record 20 of Set 7 | qasigiannguit
# Processing Record 21 of Set 7 | uusikaupunki
# Processing Record 22 of Set 7 | aborlan
# Processing Record 23 of Set 7 | miyako
# Processing Record 24 of Set 7 | kropotkin
# Processing Record 25 of Set 7 | victoria point
# Processing Record 26 of Set 7 | port-cartier
# Processing Record 27 of Set 7 | carroll
# City not found. Skipping...
# Processing Record 28 of Set 7 | antofagasta
# Processing Record 29 of Set 7 | baie-comeau
# Processing Record 30 of Set 7 | chokurdakh
# Processing Record 31 of Set 7 | pisco
# Processing Record 32 of Set 7 | tiarei
# Processing Record 33 of Set 7 | maceio
# City not found. Skipping...
# Processing Record 34 of Set 7 | qaqortoq
# Processing Record 35 of Set 7 | qingyuan
# Processing Record 36 of Set 7 | vila velha
# Processing Record 37 of Set 7 | ponta delgada
# Processing Record 38 of Set 7 | avera
# Processing Record 39 of Set 7 | berga
# Processing Record 40 of Set 7 | mengcheng
# City not found. Skipping...
# Processing Record 41 of Set 7 | harper
# Processing Record 42 of Set 7 | touros
# Processing Record 43 of Set 7 | iqaluit
# Processing Record 44 of Set 7 | kurilsk
# City not found. Skipping...
# Processing Record 45 of Set 7 | baykit
# Processing Record 46 of Set 7 | tacuati
# Processing Record 47 of Set 7 | ola
# City not found. Skipping...
# Processing Record 48 of Set 7 | palmer
# Processing Record 49 of Set 7 | camacha
# Processing Record 1 of Set 8 | broome
# City not found. Skipping...
# Processing Record 2 of Set 8 | honningsvag
# Processing Record 3 of Set 8 | bethanien
# Processing Record 4 of Set 8 | havoysund
# Processing Record 5 of Set 8 | tam ky
# Processing Record 6 of Set 8 | sindou
# Processing Record 7 of Set 8 | waverly
# Processing Record 8 of Set 8 | shubarshi
# City not found. Skipping...
# Processing Record 9 of Set 8 | tadine
# Processing Record 10 of Set 8 | durban
# Processing Record 11 of Set 8 | praya
# Processing Record 12 of Set 8 | sadasivpet
# Processing Record 13 of Set 8 | zomba
# Processing Record 14 of Set 8 | catuday
# Processing Record 15 of Set 8 | canto do buriti
# Processing Record 16 of Set 8 | asekeyevo
# City not found. Skipping...
# Processing Record 17 of Set 8 | linares
# Processing Record 18 of Set 8 | san luis
# Processing Record 19 of Set 8 | itoman
# Processing Record 20 of Set 8 | harer
# Processing Record 21 of Set 8 | sur
# Processing Record 22 of Set 8 | college
# Processing Record 23 of Set 8 | gao
# Processing Record 24 of Set 8 | moen
# Processing Record 25 of Set 8 | yulara
# Processing Record 26 of Set 8 | poya
# Processing Record 27 of Set 8 | sept-iles
# Processing Record 28 of Set 8 | moree
# Processing Record 29 of Set 8 | madera
# Processing Record 30 of Set 8 | grand-santi
# Processing Record 31 of Set 8 | nha trang
# Processing Record 32 of Set 8 | young
# Processing Record 33 of Set 8 | kobryn
# Processing Record 34 of Set 8 | saint-pierre
# Processing Record 35 of Set 8 | sioux lookout
# Processing Record 36 of Set 8 | rassvet
# Processing Record 37 of Set 8 | vazante
# City not found. Skipping...
# Processing Record 38 of Set 8 | soyo
# City not found. Skipping...
# Processing Record 39 of Set 8 | port hedland
# City not found. Skipping...
# Processing Record 40 of Set 8 | patacamaya
# Processing Record 41 of Set 8 | hwange
# Processing Record 42 of Set 8 | rio grande
# Processing Record 43 of Set 8 | marzuq
# Processing Record 44 of Set 8 | bundaberg
# Processing Record 45 of Set 8 | les cayes
# Processing Record 46 of Set 8 | matara
# Processing Record 47 of Set 8 | anton lizardo
# Processing Record 48 of Set 8 | roebourne
# Processing Record 49 of Set 8 | muroto
# City not found. Skipping...
# Processing Record 1 of Set 9 | puerto carreno
# Processing Record 2 of Set 9 | serenje
# Processing Record 3 of Set 9 | jega
# Processing Record 4 of Set 9 | dandeli
# Processing Record 5 of Set 9 | mattru
# Processing Record 6 of Set 9 | kysyl-syr
# Processing Record 7 of Set 9 | vanimo
# Processing Record 8 of Set 9 | christchurch
# Processing Record 9 of Set 9 | dalmeny
# Processing Record 10 of Set 9 | mitsamiouli
# Processing Record 11 of Set 9 | praia
# Processing Record 12 of Set 9 | axim
# Processing Record 13 of Set 9 | ende
# Processing Record 14 of Set 9 | sinnamary
# Processing Record 15 of Set 9 | kununurra
# Processing Record 16 of Set 9 | carandai
# Processing Record 17 of Set 9 | karratha
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set 9 | pacific grove
# Processing Record 19 of Set 9 | richards bay
# Processing Record 20 of Set 9 | atkarsk
# Processing Record 21 of Set 9 | west wendover
# Processing Record 22 of Set 9 | didsbury
# Processing Record 23 of Set 9 | lorengau
# Processing Record 24 of Set 9 | prince rupert
# Processing Record 25 of Set 9 | nalut
# Processing Record 26 of Set 9 | deputatskiy
# Processing Record 27 of Set 9 | coahuayana
# Processing Record 28 of Set 9 | tchaourou
# Processing Record 29 of Set 9 | bulgan
# Processing Record 30 of Set 9 | canela
# Processing Record 31 of Set 9 | padang
# Processing Record 32 of Set 9 | omsukchan
# Processing Record 33 of Set 9 | beisfjord
# Processing Record 34 of Set 9 | mitu
# Processing Record 35 of Set 9 | gremyachinsk
# Processing Record 36 of Set 9 | rovaniemi
# Processing Record 37 of Set 9 | arenapolis
# Processing Record 38 of Set 9 | mount isa
# Processing Record 39 of Set 9 | alofi
# Processing Record 40 of Set 9 | latung
# Processing Record 41 of Set 9 | dukat
# Processing Record 42 of Set 9 | guarapari
# Processing Record 43 of Set 9 | vila franca do campo
# Processing Record 44 of Set 9 | sibu
# Processing Record 45 of Set 9 | san pedro de cajas
# City not found. Skipping...
# Processing Record 46 of Set 9 | mugan
# Processing Record 47 of Set 9 | zhezkazgan
# Processing Record 48 of Set 9 | buzdyak
# Processing Record 49 of Set 9 | ulaanbaatar
# Processing Record 1 of Set 10 | zhuanghe
# Processing Record 2 of Set 10 | daru
# Processing Record 3 of Set 10 | chulym
# Processing Record 4 of Set 10 | buckeye
# Processing Record 5 of Set 10 | warner robins
# Processing Record 6 of Set 10 | sarkand
# Processing Record 7 of Set 10 | miami
# Processing Record 8 of Set 10 | saint-francois
# Processing Record 9 of Set 10 | puerto ayacucho
# City not found. Skipping...
# Processing Record 10 of Set 10 | fairbanks
# Processing Record 11 of Set 10 | seryshevo
# Processing Record 12 of Set 10 | mar del plata
# Processing Record 13 of Set 10 | kahului
# Processing Record 14 of Set 10 | faya
# City not found. Skipping...
# Processing Record 15 of Set 10 | sibolga
# Processing Record 16 of Set 10 | adrar
# Processing Record 17 of Set 10 | semnan
# Processing Record 18 of Set 10 | hiranagar
# Processing Record 19 of Set 10 | ilesha
# Processing Record 20 of Set 10 | peterhead
# Processing Record 21 of Set 10 | quepos
# Processing Record 22 of Set 10 | quibdo
# City not found. Skipping...
# Processing Record 23 of Set 10 | dauphin
# Processing Record 24 of Set 10 | ulety
# Processing Record 25 of Set 10 | quatis
# City not found. Skipping...
# Processing Record 26 of Set 10 | ugoofaaru
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 of Set 10 | acajutla
# Processing Record 28 of Set 10 | kabalo
# Processing Record 29 of Set 10 | taltal
# Processing Record 30 of Set 10 | beyneu
# Processing Record 31 of Set 10 | tuzla
# Processing Record 32 of Set 10 | zharkent
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 10 | saint-gaudens
# Processing Record 34 of Set 10 | amla
# Processing Record 35 of Set 10 | rawson
# Processing Record 36 of Set 10 | shitanjing
# Processing Record 37 of Set 10 | nelson bay
# Processing Record 38 of Set 10 | bayangol
# Processing Record 39 of Set 10 | port antonio
# Processing Record 40 of Set 10 | bonthe
# Processing Record 41 of Set 10 | svetlaya
# Processing Record 42 of Set 10 | shakiso
# Processing Record 43 of Set 10 | berlevag
# Processing Record 44 of Set 10 | itarema
# Processing Record 45 of Set 10 | yaan
# Processing Record 46 of Set 10 | aswan
# Processing Record 47 of Set 10 | mahibadhoo
# Processing Record 48 of Set 10 | ambon
# Processing Record 49 of Set 10 | grand river south east
# Processing Record 1 of Set 11 | hofn
# Processing Record 2 of Set 11 | birao
# Processing Record 3 of Set 11 | hervey bay
# Processing Record 4 of Set 11 | biak
# Processing Record 5 of Set 11 | klyuchi
# Processing Record 6 of Set 11 | kenora
# Processing Record 7 of Set 11 | green valley
# Processing Record 8 of Set 11 | bitung
# Processing Record 9 of Set 11 | tanakpur
# Processing Record 10 of Set 11 | zavodskoy
# Processing Record 11 of Set 11 | sabang
# Processing Record 12 of Set 11 | togur
# Processing Record 13 of Set 11 | harindanga
# Processing Record 14 of Set 11 | manokwari
# Processing Record 15 of Set 11 | luau
# Processing Record 16 of Set 11 | yingkou
# Processing Record 17 of Set 11 | old saybrook
# Processing Record 18 of Set 11 | agadez
# Processing Record 19 of Set 11 | prince george
# ------------------------
# Data Retrieval Complete
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictionary for establishing dataframe
weather_dict = {
    "City":city_two,
    "Cloudiness":cloudinesses,
    "Country":countries,
    "Date":dates,
    "Humidity":humidities,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds
}

# Establish dataframe
weather_dataframe = pd.DataFrame(weather_dict)

weather_dataframe.count()
# Out:
# City          509
# Cloudiness    509
# Country       509
# Date          509
# Humidity      509
# Lat           509
# Lng           509
# Max Temp      509
# Wind Speed    509
# dtype: int64

# %%
# output data to csv
weather_dataframe.to_csv(output_data_file)

# %%
# show the top of the dataframe
weather_dataframe.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0   new norfolk          75      LR  1568046166        94   6.65 -10.59
# 1  puerto ayora          40      AR  1568046222        65 -51.62 -69.23
# 2    andilamena          76      MG  1568046222        86 -17.01  48.57
# 3    tlacotepec          75      MX  1568046222        67  18.96 -99.93
# 4   mys shmidta           8      RU  1568046222        68  62.06  48.62
#
#    Max Temp  Wind Speed
# 0     78.80        6.93
# 1     44.60       17.22
# 2     60.75       12.44
# 3     59.00        1.30
# 4     53.55        1.83

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Max Temp"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature (09/09/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures/fig1.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Humidity"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Humidity (09/09/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures/fig2.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness (09/09/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures/fig3.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed (09/09/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures/fig4.png")
plt.show()

# %% [markdown]
# # ANALYSIS
# ----
#
# Observable Trend on "City Latitude vs. Max Temperature": The data goes to prove that the weather gets hotter as we get closer to the equator (0*).
#
# Observable Trend on "City Latitude vs. Humidity": Most of the data points seem to be above the 50% "Humidity" mark. Thurmore, many of the data points show a clear favoritism towards there being more humidity as we go futher up in latitude.
#
# Observable Trend on "City Latitude vs. Cloudiness": I see no strong correlation between a city's latitude and how cloudy it is. The data seems very balanced. We should take note however, of the three rows of possible trends represented at the 0%, 75% and 100% "Cloudiness."
#
# Observable Trend on "City Latitude vs. Wind Speed": The data shows that most of the Wind Speeds are between 0 and 15 "mph" regardless of the latitdude of a city. Thus, I am unable to see a correlation between the latitude of a city and how windy it is.
